# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import MySQLdb

# %% [markdown]
# # Extracting data

# %%
ca = pd.read_csv("F:/CAvideos.csv")
us = pd.read_csv("F:/USvideos.csv")

# %%
ca.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
us.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
print(ca.columns)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
print(us.columns)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %% [markdown]
# # Adding country column and cleaning

# %%
ca = ca[['video_id', 'trending_date', 'title','channel_title', 'category_id', 'publish_time', 'views', 'likes','dislikes', 'comment_count'  ]].copy()
ca.insert(1,'country','CA')
ca
# Out:
#           video_id country trending_date  \
# 0      n1WpP7iowLc      CA      17.14.11
# 1      0dBIkQ4Mz1M      CA      17.14.11
# 2      5qpjK5DgCt4      CA      17.14.11
# 3      d380meD0W0M      CA      17.14.11
# 4      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 40876  sGolxsMSGfQ      CA      18.14.06
# 40877  8HNuRNi8t70      CA      18.14.06
# 40878  GWlKEM3m2EE      CA      18.14.06
# 40879  lbMKLzQ4cNQ      CA      18.14.06
# 40880  POTgw38-m58      CA      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...

# %%
us = us[['video_id', 'trending_date', 'title','channel_title', 'category_id', 'publish_time', 'views', 'likes','dislikes', 'comment_count'  ]].copy()
us.insert(1,'country','US')
us
# Out:
#           video_id country trending_date  \
# 0      2kyS6SvSYSE      US      17.14.11
# 1      1ZAPwfrtAFY      US      17.14.11
# 2      5qpjK5DgCt4      US      17.14.11
# 3      puqaWrEC7tY      US      17.14.11
# 4      d380meD0W0M      US      17.14.11
# ...            ...     ...           ...
# 40944  BZt0qjTWNhw      US      18.14.06
# 40945  1h7KV2sjUWY      US      18.14.06
# 40946  D6Oy4LfoqsU      US      18.14.06
# 40947  oV0zkMe1K8s      US      18.14.06
# 40948  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# ...

# %% [markdown]
# # Importing Json file

# %%
import json
from pandas.io.json import json_normalize
cat=[]

# %%
c = pd.read_json("F:/CA_category_id.json")
u = pd.read_json("F:/US_category_id.json")

# %%
c
# Out:
#                                  kind  \
# 0   youtube#videoCategoryListResponse
# 1   youtube#videoCategoryListResponse
# 2   youtube#videoCategoryListResponse
# 3   youtube#videoCategoryListResponse
# 4   youtube#videoCategoryListResponse
# 5   youtube#videoCategoryListResponse
# 6   youtube#videoCategoryListResponse
# 7   youtube#videoCategoryListResponse
# 8   youtube#videoCategoryListResponse
# 9   youtube#videoCategoryListResponse
# 10  youtube#videoCategoryListResponse
# 11  youtube#videoCategoryListResponse
# 12  youtube#videoCategoryListResponse
# 13  youtube#videoCategoryListResponse
# 14  youtube#videoCategoryListResponse
# 15  youtube#videoCategoryListResponse
# 16  youtube#videoCategoryListResponse
# 17  youtube#videoCategoryListResponse
# 18  youtube#videoCategoryListResponse
# 19  youtube#videoCategoryListResponse
# 20  youtube#videoCategoryListResponse
# 21  youtube#videoCategoryListResponse
# 22  youtube#videoCategoryListResponse
# ...

# %% [markdown]
# # Transforming

# %%
countries = ['F:/CA_category_id.json','F:/US_category_id.json']

# %%
for country in countries:
    c=json.load(open(country, 'r'))
    for data in c['items']:
        cat.append([data['id'],country[3:5],data['snippet']['title']])
            
cat
# Out:
# [['1', 'CA', 'Film & Animation'],
#  ['2', 'CA', 'Autos & Vehicles'],
#  ['10', 'CA', 'Music'],
#  ['15', 'CA', 'Pets & Animals'],
#  ['17', 'CA', 'Sports'],
#  ['18', 'CA', 'Short Movies'],
#  ['19', 'CA', 'Travel & Events'],
#  ['20', 'CA', 'Gaming'],
#  ['21', 'CA', 'Videoblogging'],
#  ['22', 'CA', 'People & Blogs'],
#  ['23', 'CA', 'Comedy'],
#  ['24', 'CA', 'Entertainment'],
#  ['25', 'CA', 'News & Politics'],
#  ['26', 'CA', 'Howto & Style'],
#  ['27', 'CA', 'Education'],
#  ['28', 'CA', 'Science & Technology'],
#  ['30', 'CA', 'Movies'],
#  ['31', 'CA', 'Anime/Animation'],
#  ['32', 'CA', 'Action/Adventure'],
#  ['33', 'CA', 'Classics'],
#  ['34', 'CA', 'Comedy'],
#  ['35', 'CA', 'Documentary'],
#  ['36', 'CA', 'Drama'],
#  ['37', 'CA', 'Family'],
#  ['38', 'CA', 'Foreign'],
#  ['39', 'CA', 'Horror'],
#  ['40', 'CA', 'Sci-Fi/Fantasy'],
#  ['41', 'CA', 'Thriller'],
#  ['42', 'CA', 'Shorts'],
#  ['43', 'CA', 'Shows'],
#  ['44', 'CA', 'Trailers'],
# ...

# %% [markdown]
# # Mapping Category name

# %%
categoryCA_map={1:'Film & Animation', 2:'Autos & Vehicles', 10:'Music', 15:'Pets & Animals', 17:'Sports',18: 'Short Movies',
               19:'Travel & Events', 20:'Gaming',21: 'Videoblogging',22: 'People & Blogs',23: 'Comedy',24: 'Entertainment',
               25: 'News & Politics',26: 'Howto & Style',27: 'Education', 28: 'Science & Technology',29: 'Nonprofits & Activism',30: 'Movies', 
               31: 'Anime/Animation', 32: 'Action/Adventure',33: 'Classics', 34:'Comedy', 35: 'Documentary', 36: 'Drama',
               37: 'Family', 38: 'Foreign', 39: 'Horror', 40: 'Sci-Fi/Fantasy', 41: 'Thriller', 42: 'Shorts', 43: 'Shows', 44: 'Trailers'}

ca['category_name']=ca['category_id'].map(categoryCA_map)

ca = ca[['video_id','country', 'trending_date', 'title','channel_title', 'category_id','category_name', 'publish_time',
                           'views', 'likes','dislikes', 'comment_count'  ]]

ca.insert(0,'ID',range(1,1+len(ca)))
ca=ca.set_index('ID')

ca
# Out:
#           video_id country trending_date  \
# ID
# 1      n1WpP7iowLc      CA      17.14.11
# 2      0dBIkQ4Mz1M      CA      17.14.11
# 3      5qpjK5DgCt4      CA      17.14.11
# 4      d380meD0W0M      CA      17.14.11
# 5      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 40877  sGolxsMSGfQ      CA      18.14.06
# 40878  8HNuRNi8t70      CA      18.14.06
# 40879  GWlKEM3m2EE      CA      18.14.06
# 40880  lbMKLzQ4cNQ      CA      18.14.06
# 40881  POTgw38-m58      CA      18.14.06
#
#                                                    title     channel_title  \
# ID
# 1             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 2                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 3      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 4                               I Dare You: GOING BALD!?          nigahiga
# 5            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...

# %%
categoryCA_map={1:'Film & Animation', 2:'Autos & Vehicles', 10:'Music', 15:'Pets & Animals', 17:'Sports',18: 'Short Movies',
               19:'Travel & Events', 20:'Gaming',21: 'Videoblogging',22: 'People & Blogs',23: 'Comedy',24: 'Entertainment',
               25: 'News & Politics',26: 'Howto & Style',27: 'Education', 28: 'Science & Technology',29: 'Nonprofits & Activism',30: 'Movies', 
               31: 'Anime/Animation', 32: 'Action/Adventure',33: 'Classics', 34:'Comedy', 35: 'Documentary', 36: 'Drama',
               37: 'Family', 38: 'Foreign', 39: 'Horror', 40: 'Sci-Fi/Fantasy', 41: 'Thriller', 42: 'Shorts', 43: 'Shows', 44: 'Trailers'}

us['category_name']=ca['category_id'].map(categoryCA_map)

us = us[['video_id','country', 'trending_date', 'title','channel_title', 'category_id','category_name', 'publish_time',
                           'views', 'likes','dislikes', 'comment_count'  ]]

us.insert(0,'ID',range(1,1+len(us)))
us=us.set_index('ID')

us
# Out:
#           video_id country trending_date  \
# ID
# 1      2kyS6SvSYSE      US      17.14.11
# 2      1ZAPwfrtAFY      US      17.14.11
# 3      5qpjK5DgCt4      US      17.14.11
# 4      puqaWrEC7tY      US      17.14.11
# 5      d380meD0W0M      US      17.14.11
# ...            ...     ...           ...
# 40945  BZt0qjTWNhw      US      18.14.06
# 40946  1h7KV2sjUWY      US      18.14.06
# 40947  D6Oy4LfoqsU      US      18.14.06
# 40948  oV0zkMe1K8s      US      18.14.06
# 40949  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# ID
# 1                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 2      The Trump Presidency: Last Week Tonight with J...
# 3      Racist Superman | Rudy Mancuso, King Bach & Le...
# 4                       Nickelback Lyrics: Real or Fake?
# 5                               I Dare You: GOING BALD!?
# ...                                                  ...
# ...

# %%
df=pd.concat([ca,us])
df = df.reset_index(drop=True)
df.insert(0,'ID',range(1,1+len(df)))
df=df.set_index('ID')
df
# Out:
#           video_id country trending_date  \
# ID
# 1      n1WpP7iowLc      CA      17.14.11
# 2      0dBIkQ4Mz1M      CA      17.14.11
# 3      5qpjK5DgCt4      CA      17.14.11
# 4      d380meD0W0M      CA      17.14.11
# 5      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 81826  BZt0qjTWNhw      US      18.14.06
# 81827  1h7KV2sjUWY      US      18.14.06
# 81828  D6Oy4LfoqsU      US      18.14.06
# 81829  oV0zkMe1K8s      US      18.14.06
# 81830  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# ID
# 1             Eminem - Walk On Water (Audio) ft. Beyoncé
# 2                          PLUSH - Bad Unboxing Fan Mail
# 3      Racist Superman | Rudy Mancuso, King Bach & Le...
# 4                               I Dare You: GOING BALD!?
# 5            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# ...

# %%
df.count()
# Out:
# video_id         81830
# country          81830
# trending_date    81830
# title            81830
# channel_title    81830
# category_id      81830
# category_name    81762
# publish_time     81830
# views            81830
# likes            81830
# dislikes         81830
# comment_count    81830
# dtype: int64

# %% [markdown]
# # Loading Dataframe to Mysql

# %%
pip install mysql-connector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import mysql.connector
from pymysql  import connect

# %%
data_base = connect(host = 'localhost',
                   user = 'root',
                   password = 'test'
                  )

cur = data_base.cursor()
 
query = 'show databases'

cur.execute(query)

data_bases = cur.fetchall()

for data in data_bases:
    print(data)
# Out:
# ('geo',)
# ('imdb',)
# ('information_schema',)
# ('my_assig',)
# ('mysql',)
# ('new_schema',)
# ('performance_schema',)
# ('prathyu',)
# ('sakila',)
# ('store',)
# ('student',)
# ('sys',)
# ('world',)

# %%
data_base = connect(host = 'localhost',
                   user = 'root',
                   password = 'test',
                   database = 'my_assig'
                  )
cur = data_base.cursor()
 
query = 'show tables'

cur.execute(query)
# Out:
# 1

# %%
pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql
# Out:
# ...
#
# ...

# %% [markdown]
# # Connecting df to database

# %%
from sqlalchemy import create_engine
my_conn = create_engine("mysql+mysqldb://root:test@localhost/my_assig")

# %%
df
# Out:
#           video_id country trending_date  \
# ID
# 1      n1WpP7iowLc      CA      17.14.11
# 2      0dBIkQ4Mz1M      CA      17.14.11
# 3      5qpjK5DgCt4      CA      17.14.11
# 4      d380meD0W0M      CA      17.14.11
# 5      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 81826  BZt0qjTWNhw      US      18.14.06
# 81827  1h7KV2sjUWY      US      18.14.06
# 81828  D6Oy4LfoqsU      US      18.14.06
# 81829  oV0zkMe1K8s      US      18.14.06
# 81830  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# ID
# 1             Eminem - Walk On Water (Audio) ft. Beyoncé
# 2                          PLUSH - Bad Unboxing Fan Mail
# 3      Racist Superman | Rudy Mancuso, King Bach & Le...
# 4                               I Dare You: GOING BALD!?
# 5            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# ...

# %% [markdown]
# # Data frame is loaded to mysql

# %%
finalresult = pd.DataFrame(data = df)
print(df)
finalresult.to_sql(con=my_conn, name= 'etl', if_exists = 'append', index = False)
# Out:
#           video_id country trending_date  \
# ID
# 1      n1WpP7iowLc      CA      17.14.11
# 2      0dBIkQ4Mz1M      CA      17.14.11
# 3      5qpjK5DgCt4      CA      17.14.11
# 4      d380meD0W0M      CA      17.14.11
# 5      2Vv-BfVoq4g      CA      17.14.11
# ...            ...     ...           ...
# 81826  BZt0qjTWNhw      US      18.14.06
# 81827  1h7KV2sjUWY      US      18.14.06
# 81828  D6Oy4LfoqsU      US      18.14.06
# 81829  oV0zkMe1K8s      US      18.14.06
# 81830  ooyjaVdt-jA      US      18.14.06
#
#                                                    title  \
# ID
# 1             Eminem - Walk On Water (Audio) ft. Beyoncé
# 2                          PLUSH - Bad Unboxing Fan Mail
# 3      Racist Superman | Rudy Mancuso, King Bach & Le...
# 4                               I Dare You: GOING BALD!?
# 5            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# ...

# %%
data_base = connect(host = 'localhost',
                   user = 'root',
                   password = 'test',
                   database = 'my_assig'
                  )
cur = data_base.cursor()
 
query = 'show tables'

cur.execute(query)
# Out:
# 1

# %%
data_base = connect(host = 'localhost',
                   user = 'root',
                   password = 'test',
                   database = 'my_assig'
                  )
cur = data_base.cursor()
 
query = 'select * from  etl'

cur.execute(query)
# Out:
# 490980

# %%
pandas_dataframe = pd.read_sql(query,data_base)

# %%
display(pandas_dataframe)
# Out:
#            video_id country trending_date  \
# 0       n1WpP7iowLc      CA      17.14.11
# 1       0dBIkQ4Mz1M      CA      17.14.11
# 2       5qpjK5DgCt4      CA      17.14.11
# 3       d380meD0W0M      CA      17.14.11
# 4       2Vv-BfVoq4g      CA      17.14.11
# ...             ...     ...           ...
# 490975  BZt0qjTWNhw      US      18.14.06
# 490976  1h7KV2sjUWY      US      18.14.06
# 490977  D6Oy4LfoqsU      US      18.14.06
# 490978  oV0zkMe1K8s      US      18.14.06
# 490979  ooyjaVdt-jA      US      18.14.06
#
#                                                     title  \
# 0              Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                           PLUSH - Bad Unboxing Fan Mail
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                                I Dare You: GOING BALD!?
# 4             Ed Sheeran - Perfect (Official Music Video)
# ...                                                   ...
# ...
